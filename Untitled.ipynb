# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
file = pd.read_csv('TEST TASK (dataset).csv', encoding='UTF-8')
file = file.dropna()
file['target_sub_ltv_day30'].min()
# Out:
# -2.829603837323869

# %%
file.tail()
# Out:
#          total_sessions_day0  total_sessions_day1  total_sessions_day3  \
# 1467827                 11.0                 11.0                 11.0
# 1467828                  2.0                  3.0                  6.0
# 1467829                  3.0                  5.0                 11.0
# 1467830                  5.0                  5.0                  5.0
# 1467831                  6.0                  7.0                  7.0
#
#          total_sessions_day7  chapters_finished_day0  chapters_finished_day1  \
# 1467827                 11.0                       9                       9
# 1467828                  7.0                       5                       9
# 1467829                 13.0                       5                       9
# 1467830                  5.0                      24                      24
# 1467831                  7.0                      15                      15
#
# ...

# %%
file.columns
# Out:
# Index(['total_sessions_day0', 'total_sessions_day1', 'total_sessions_day3',
#        'total_sessions_day7', 'chapters_finished_day0',
#        'chapters_finished_day1', 'chapters_finished_day3',
#        'chapters_finished_day7', 'chapters_opened_day0',
#        'chapters_opened_day1', 'chapters_opened_day3', 'chapters_opened_day7',
#        'chapters_closed_day0', 'chapters_closed_day1', 'chapters_closed_day3',
#        'chapters_closed_day7', 'diamonds_received_day0',
#        'diamonds_received_day1', 'diamonds_received_day3',
#        'diamonds_received_day7', 'diamonds_spent_day0', 'diamonds_spent_day1',
#        'diamonds_spent_day3', 'diamonds_spent_day7', 'tickets_spent_day0',
#        'tickets_spent_day1', 'tickets_spent_day3', 'tickets_spent_day7',
#        'retained_day1', 'retained_day3', 'retained_day7',
#        'chapters_finished_session1', 'chapters_finished_session3',
#        'chapters_finished_session9', 'chapters_opened_session1',
# ...

# %%
file.shape
# Out:
# (1467832, 63)

# %%
sns.set_theme(style="darkgrid")

sns.jointplot(x="diamonds_spent_day7", y="target_iap_ltv_day30", data=file,
                  xlim=(0, 60), ylim=(0, 12),
                  color="m", height=7)

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(10.5, 10.5)
sns.regplot(x="diamonds_spent_day7", y="target_iap_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 10.5)
sns.regplot(x="tickets_spent_day7", y="target_iap_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 15.5)
sns.regplot(x="app_sub_ltv_day3", y="target_sub_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 15.5)
sns.regplot(x="ad_ltv_day3", y="target_ad_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(10.5, 15.5)
sns.regplot(x="app_iap_ltv_day3", y="target_iap_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_style('ticks')
fig, ax = plt.subplots()
fig.set_size_inches(15.5, 15.5)
sns.regplot(x="chapters_opened_day7", y="target_iap_ltv_day30", ci=None, fit_reg=True, data=file, ax=ax)
sns.despine()

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="chapters_opened_day7", y="target_iap_ltv_day30",
             data=file)
# Out:
# <AxesSubplot:xlabel='chapters_opened_day7', ylabel='target_iap_ltv_day30'>

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x="diamonds_spent_day7", y="target_iap_ltv_day30",
             data=file)
# Out:
# <AxesSubplot:xlabel='diamonds_spent_day7', ylabel='target_iap_ltv_day30'>

# %%
f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    file,
    x="diamonds_spent_day7", y="target_iap_ltv_day30", hue="cut",
    multiple="stack",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set_xticks([500, 1000, 2000, 5000, 10000])
